# %% [markdown]
# <a href="https://colab.research.google.com/github/pearlncu/Pearl/blob/main/Correlation-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
np.random.seed(1)

# %%
x=np.random.randint(0,50,1000)
print(x)
# Out:
# [ 0 17 37 12  6 20 15 45 29  6 14 42 13 12 17 42 47 40 43 11 25 25 42  8
#  42 44 44 32 28  5 20  7 36 33 39 48 19 21  9 13 11 37  3 35 37 41  9 15
#  29 40 21 12 29 25 22 37 43 15 22 27 36 45  2  3 31  8  8 35 25 16 42 21
#  10 32  6  9 37  2 45 13 41 33  3  4 30  1  5 24 47 10 36  1 13  6 16 42
#  45 33 29  5 25 23 29 31 42  5 22 40 41 17 46 39 19 15 11 29 44 42 29 25
#  15 36  4 18 48 30 11 42 22 20 28 32 22  4  2 22  2  9  1 33 16  7  5  5
#  37 42 15 35 46 17 23 20  4 23 25 46 31 25 18 11 45  6 20  5  3 39 11 44
#  44 26 21 44 16 36 37 46 11  0 35 19 22 12 10  7 36 31 23 28  0 39 32  2
#  46 15 45 37 26 24 33 34 25 14 19 45 19 11 20 37 32 15 34 41 38 39  6 36
#   8  0 23 42 18 44 43 29 37  5  2 40 36 30 19 19 23 30 17 34 39 23 16  9
#  27 30 48 49 37 21  0 31 29 18 39 44 49 44 23 36 17 25  5 43 10 21  4 43
#  46 45 10 12 35 17 11  4 23 26  1 16 11 37 25 24 16 15 41 20 19 45 47 33
#   1 29 38 19  5 27  0 19 40 11  5  6 29 35 22 17 28 33  9 20 29 47 32 43
# ...

# %%
y= x + np.random.normal(0,10,1000)
print(y)
# Out:
# [-1.21784605e+01  1.75769209e+01  4.30835538e+01  8.48308124e+00
#   9.68665693e+00  2.10463232e+01  1.15571085e+01  4.43918253e+01
#   2.70497912e+01 -1.37424776e+01 -9.91628618e-01  4.63285223e+01
#  -7.88347042e+00  2.35838179e+01  2.90028862e+00  4.23052529e+01
#   5.17213592e+01  3.36326498e+01  5.46258855e+01 -2.70853549e+00
#   3.40676638e+01  2.64855655e+01  4.04881418e+01  1.81169595e+01
#   4.73925382e+01  3.19552256e+01  5.81181061e+01  4.20399640e+01
#   2.90380768e+01  6.49687529e+00  3.33623672e+01  2.35817225e+01
#   4.21265849e+01  2.13737857e+01  4.02025015e+01  5.62001991e+01
#   1.06550166e+01  8.94133088e+00  9.05778392e+00  1.41236385e+01
#   1.47782979e+01  4.93029934e+01 -1.88242540e+01  3.59986145e+01
#   3.49432228e+01  4.11574925e+01  1.06743325e+01  2.52574955e+01
#   3.45893274e+01  3.95430008e+01  2.18911753e+01  1.30535739e+01
#   2.76703422e+01  3.82201378e+01  2.87761714e+00  2.29850381e+01
# ...

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.82505829],
#        [0.82505829, 1.        ]])

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')
plt.scatter(x,y)
plt.show()

# %%
y= x - np.random.normal(0,10,1000)
print(y)
# Out:
# [-6.16791365e-01  2.41081529e+01  4.95121058e+01  2.36893959e+01
#  -4.94731757e+00  1.18983240e+01  1.88705067e+01  6.57284809e+01
#   2.33130257e+01 -5.46830729e+00  7.79608585e+00  4.46406316e+01
#   2.73220509e+01  1.30010884e+01  2.61196379e+01  5.00469233e+01
#   4.79202110e+01  4.65055529e+01  4.24180623e+01  1.85926986e+00
#   4.01724173e+01  2.24736865e+01  3.80213398e+01  1.10354527e+01
#   6.25564329e+01  5.29091817e+01  2.13366668e+01  2.49079480e+01
#   4.01211498e+01  8.98753300e+00  2.45077084e+01  6.17636860e+00
#   3.31182824e+01  2.51381753e+01  3.78710885e+01  5.69094654e+01
#   1.01661757e+01  2.88776509e+01  3.65096947e+00 -5.01616715e+00
#   9.77162875e+00  5.38267113e+01 -3.06601644e+00  3.11827747e+01
#   4.77266510e+01  3.48654369e+01  8.55774663e+00  2.59095113e+01
#   2.73965321e+01  4.18200459e+01  3.95138507e+01  9.90124167e+00
#   4.50673588e+01  2.04269523e+01  3.64848170e+01  3.24324827e+01
# ...

# %%
np.corrcoef(x,y)
# Out:
# array([[1.       , 0.8144352],
#        [0.8144352, 1.       ]])

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')
plt.scatter(x,y)
plt.show()

# %%
x=np.random.randint(0,50,1000)
y=100-x+np.random.normal(0,5,1000)
np.corrcoef(x,y)
# Out:
# array([[ 1.        , -0.94783482],
#        [-0.94783482,  1.        ]])

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')
plt.scatter(x,y)
plt.show()

# %%
x1=np.random.randint(0,50,1000)
y1=100-x1+np.random.normal(0,5,1000)
np.corrcoef(x1,y1)
# Out:
# array([[ 1.        , -0.94943237],
#        [-0.94943237,  1.        ]])

# %%
print('z and x1')
np.corrcoef(x1,z)
plt.scatter(x1,z)
plt.show()
print('z and y1')
np.corrcoef(y1,z)
plt.scatter(y1,z)
plt.show()
# Out:
# z and x1
# z and y1

# %%
z=400-x+np.random.normal(0,10,1000)
np.corrcoef(x,z)
# Out:
# array([[ 1.        , -0.82117978],
#        [-0.82117978,  1.        ]])

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')
plt.scatter(x,z)
plt.show()

# %%
z=400-x+np.random.normal(0,10,1000)
np.corrcoef(y,z)
# Out:
# array([[1.        , 0.77200071],
#        [0.77200071, 1.        ]])

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')
plt.scatter(y,z)
plt.show()

# %%
import pandas as pd
df = pd.DataFrame({'a': np.random.randint(0, 50,1000)})
df['b'] = df['a'] + np.random.normal(0,10,1000)
df['c'] = 100-df['a'] + np.random.normal(0,5,1000)
df['d'] = np.random.randint(0,50,1000)
df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.813031 -0.942855 -0.021699
# b  0.813031  1.000000 -0.774622 -0.020091
# c -0.942855 -0.774622  1.000000  0.017079
# d -0.021699 -0.020091  0.017079  1.000000

# %%
pd.plotting.scatter_matrix(df,figsize=(6,6))
plt.show()

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)),df.columns)
plt.yticks(range(len(df.columns)),df.columns)
plt.colorbar()
plt.show()
